# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from pandas) (1.23.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv('car data.csv')
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print('Fuel_Type: ',df['Fuel_Type'].unique())
print('Seller_Type: ',df['Seller_Type'].unique())
print('Transmission: ',df['Transmission'].unique())
print('Owner: ',df['Owner'].unique())
# Out:
# Fuel_Type:  ['Petrol' 'Diesel' 'CNG']
# Seller_Type:  ['Dealer' 'Individual']
# Transmission:  ['Manual' 'Automatic']
# Owner:  [0 1 3]

# %% [markdown]
# #To check missing values

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
final_dataset = df[['Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
       'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner']]

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner
# 0       Manual      0
# 1       Manual      0
# 2       Manual      0
# 3       Manual      0
# 4       Manual      0

# %%
final_dataset['Current_Year'] = 2022

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year
# 0       Manual      0          2022
# 1       Manual      0          2022
# 2       Manual      0          2022
# 3       Manual      0          2022
# 4       Manual      0          2022

# %%
final_dataset['Total_years'] = final_dataset['Current_Year']  - final_dataset['Year']

# %%
final_dataset.head()
# Out:
#    Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0  2014           3.35           5.59       27000    Petrol      Dealer
# 1  2013           4.75           9.54       43000    Diesel      Dealer
# 2  2017           7.25           9.85        6900    Petrol      Dealer
# 3  2011           2.85           4.15        5200    Petrol      Dealer
# 4  2014           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Current_Year  Total_years
# 0       Manual      0          2022            8
# 1       Manual      0          2022            9
# 2       Manual      0          2022            5
# 3       Manual      0          2022           11
# 4       Manual      0          2022            8

# %%
final_dataset.drop(['Year','Current_Year'], axis = 1, inplace = True)

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Total_years
# 0       Manual      0            8
# 1       Manual      0            9
# 2       Manual      0            5
# 3       Manual      0           11
# 4       Manual      0            8

# %%
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Selling_Price  301 non-null    float64
#  1   Present_Price  301 non-null    float64
#  2   Kms_Driven     301 non-null    int64
#  3   Fuel_Type      301 non-null    object
#  4   Seller_Type    301 non-null    object
#  5   Transmission   301 non-null    object
#  6   Owner          301 non-null    int64
#  7   Total_years    301 non-null    int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 18.9+ KB

# %%
final_dataset = pd.get_dummies(final_dataset, drop_first = True)

# %%
final_dataset
# Out:
#      Selling_Price  Present_Price  Kms_Driven  Owner  Total_years  \
# 0             3.35           5.59       27000      0            8
# 1             4.75           9.54       43000      0            9
# 2             7.25           9.85        6900      0            5
# 3             2.85           4.15        5200      0           11
# 4             4.60           6.87       42450      0            8
# ..             ...            ...         ...    ...          ...
# 296           9.50          11.60       33988      0            6
# 297           4.00           5.90       60000      0            7
# 298           3.35          11.00       87934      0           13
# 299          11.50          12.50        9000      0            5
# 300           5.30           5.90        5464      0            6
#
#      Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                   0                 1                       0
# 1                   1                 0                       0
# 2                   0                 1                       0
# 3                   0                 1                       0
# 4                   1                 0                       0
# ..                ...               ...                     ...
# 296                 1                 0                       0
# 297                 0                 1                       0
# 298                 0                 1                       0
# 299                 1                 0                       0
# 300                 0                 1                       0
#
#      Transmission_Manual
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ..                   ...
# 296                    1
# 297                    1
# 298                    1
# 299                    1
# 300                    1
#
# [301 rows x 9 columns]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (0.12.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from seaborn) (1.4.4)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from matplotlib>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from matplotlib>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from matplotlib>=3.1->seaborn) (4.37.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from matplotlib>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from matplotlib>=3.1->seaborn) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from matplotlib>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from matplotlib>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from pandas>=0.25->seaborn) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\shoba\appdata\roaming\python\python39\site-packages (from python-dateutil>=2.7->matplotlib>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.pairplot(final_dataset)

# %%
import matplotlib.pyplot as plt

# %%
final_dataset.corr()
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# Total_years                 -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         Total_years  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price             -0.236141          0.552339         -0.540571
# Present_Price              0.047584          0.473306         -0.465244
# Kms_Driven                 0.524342          0.172515         -0.172874
# Owner                      0.182104         -0.053469          0.055687
# Total_years                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel          -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol           0.059959         -0.979648          1.000000
# Seller_Type_Individual     0.039896         -0.350467          0.358321
# Transmission_Manual       -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# Total_years                           0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
plt.figure(figsize=(10,7)) #plot heat map  
g=sns.heatmap(final_dataset.corr(),annot=True,cmap="RdYlGn")

# %%
final_dataset.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  Total_years  \
# 0           3.35           5.59       27000      0            8
# 1           4.75           9.54       43000      0            9
# 2           7.25           9.85        6900      0            5
# 3           2.85           4.15        5200      0           11
# 4           4.60           6.87       42450      0            8
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
X = final_dataset.iloc[:,1:]
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  Total_years  Fuel_Type_Diesel  \
# 0           5.59       27000      0            8                 0
# 1           9.54       43000      0            9                 1
# 2           9.85        6900      0            5                 0
# 3           4.15        5200      0           11                 0
# 4           6.87       42450      0            8                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
y = final_dataset.iloc[:,0:1]
y.head()
# Out:
#    Selling_Price
# 0           3.35
# 1           4.75
# 2           7.25
# 3           2.85
# 4           4.60

# %%
pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-1.1.2-cp39-cp39-win_amd64.whl (7.4 MB)
#      ---------------------------------------- 7.4/7.4 MB 9.9 MB/s eta 0:00:00
# Collecting joblib>=1.0.0
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\shoba\anaconda3\envs\car_prediction\lib\site-packages (from scikit-learn->sklearn) (1.23.2)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.9.1-cp39-cp39-win_amd64.whl (38.6 MB)
#      ---------------------------------------- 38.6/38.6 MB 9.4 MB/s eta 0:00:00
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1304 sha256=89aeb1fc5e067ca873095680a8208119ba11f4982bdfdff112ec9f9eeedcfd6e
#   Stored in directory: c:\users\shoba\appdata\local\pip\cache\wheels\e4\7b\98\b6466d71b8d738a0c547008b9eb39bf8676d1ff6ca4b22af1c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.2.0 scikit-learn-1.1.2 scipy-1.9.1 sklearn-0.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# C:\Users\shoba\AppData\Local\Temp\ipykernel_25892\1093807828.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model.fit(X,y)
# ExtraTreesRegressor()

# %%
print(model.feature_importances_)
# Out:
# [0.4043486  0.03759059 0.00124059 0.07910138 0.20293752 0.0155036
#  0.13153593 0.12774179]

# %%
#plot graph of feature importances for better visualization 
feat_importances = pd.Series(model.feature_importances_, index=X.columns) 
feat_importances.nlargest(5).plot(kind='barh') 
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
y_train
# Out:
#      Selling_Price
# 102           1.65
# 80           14.73
# 245           5.20
# 163           0.45
# 131           0.75
# ..             ...
# 203           2.95
# 255           3.00
# 72            7.45
# 235           9.10
# 37            0.35
#
# [240 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()

# %%
import numpy as np
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 50, stop = 1200, num = 24)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(3, 30, num =10)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
random_grid = {'n_estimators': n_estimators,

'max_features': max_features,

'max_depth': max_depth,

'min_samples_split': min_samples_split,

'min_samples_leaf': min_samples_leaf}

# %%
rf_random = RandomizedSearchCV(estimator = rf,

param_distributions = random_grid,
               n_iter = 10, cv = 5, verbose=2, random_state=35, n_jobs = -1)

# %%
rf_random.fit(X_train,y_train)

# this prints the contents of the parameters in the random grid
print ('Random grid: ', random_grid, '\n')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\shoba\anaconda3\envs\car_prediction\lib\site-packages\sklearn\model_selection\_search.py:910: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\Users\shoba\anaconda3\envs\car_prediction\lib\site-packages\sklearn\ensemble\_forest.py:416: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0` or remove this parameter as it is also the default value for RandomForestRegressors and ExtraTreesRegressors.
#   warn(
# Random grid:  {'n_estimators': [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200], 'max_features': ['auto', 'sqrt'], 'max_depth': [3, 6, 9, 12, 15, 18, 21, 24, 27, 30], 'min_samples_split': [2, 5, 10, 15, 100], 'min_samples_leaf': [1, 2, 5, 10]}

# %%
# print the best parameters
print ('Best Parameters: ', rf_random.best_params_, ' \n')
# Out:
# Best Parameters:  {'n_estimators': 400, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 12}

# %%
rf_random.best_score_
# Out:
# 0.8837954652965404

# %%
predictions=rf_random.predict(X_test)

# %%
print(predictions)
# Out:
# [ 6.68030898  2.90094137  0.53417256  3.01176205  1.05902     5.31557361
#   0.82790113  3.23588046  9.23831639  0.57318727  8.46633635  3.82226493
#   5.30916002  4.12539534  0.17342402  0.40982573  7.37824826  5.30356007
#   5.01079633  7.39330035  5.07848552  3.72907923  9.12051473  7.52518312
#  12.6446026   3.19302411  3.02032563  0.64043643  0.24779929  0.46654622
#   0.2884824   0.22970316  5.14812063 26.09457783 21.50778686  4.09720813
#   3.38380585  0.89577543  0.28936038  4.03164916  9.60855842 11.01040381
#   0.300763    4.39332366  4.38184494  4.57123864  6.07570501  7.48009598
#   7.62925258  1.17942589  4.77532599  0.45748619  2.86768681  4.36302808
#   1.18276809  0.15062826 24.67875223  0.62018812  5.93637029  5.92626399
#   0.26217358]

# %%
plt.scatter(y_test,predictions)

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 0.8115289197596575
# MSE: 3.463513584950068
# RMSE: 1.8610517416101218
